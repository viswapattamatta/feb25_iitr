# %%
# Basic tree implementation

# %%
class Node() :
    
    def __init__(self,value,left=None,right=None) :
        print(f"initializing Tree")
        self.value = value
        self.left = left
        self.right = right
    def count(self) :
        print(f"counting for {self.value}")
        count = 1
        if(self.left != None) :
            count += self.left.count()
            print(f"counting left {self.value}")
        if(self.right != None) :
            count += self.right.count()
            print(f"counting right {self.value}")
        return count
    def total(self) :
        total = self.value
        if(self.left != None) :
            total += self.left.total()
        if(self.right != None) :
            total += self.right.total()
        return total
    def min(self) :
        min_val = self.value
        if(self.left != None) :

# %%
n6 = Node(6)
n7 = Node(7)
n5 = Node(5,n6,n7)
n4 = Node(4)
n2 = Node(2,n4,n5)
n3 = Node(3)
n1 = Node(1,n2,n3)
#n2 = Node(2,n,None)
#n3 = Node(3,n2,None)
n1.count()
n2.total()
# Out:
# initializing Tree
# initializing Tree
# initializing Tree
# initializing Tree
# initializing Tree
# initializing Tree
# initializing Tree
# counting for 1
# counting for 2
# counting for 4
# counting left 2
# counting for 5
# counting for 6
# counting left 5
# counting for 7
# counting right 5
# counting right 2
# counting left 1
# counting for 3
# counting right 1
# 24
